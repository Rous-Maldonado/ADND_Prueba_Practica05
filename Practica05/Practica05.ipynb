# %% [markdown]
# # Practica05: Manejo de Heatm en Analisis de Datos

# %% [markdown]
# ## Unidad 2: Tratamiento y Exploración de los Datos

# %% [markdown]
# **Programa de Estudios:** Ingeniería en Entornos Virtuales y Nergocios Digitales \
# **Asignatura:** Analítica de Datos para Negocios Digitales \
# **Docente:** M.T.I Marco A. Ramírez Hernández \
# **Periodo:** Mayo - Agosto 2026

# %% [markdown]
# ## Ciencia de Datos para el Bien Social: DonorsChoose
#
# DonorsChoose es una organización sin fines de lucro con sede en los Estados Unidos que permite a las personas donar directamente a proyectos de aulas de escuelas públicas. Hasta enero de 2018, DonorsChoose.org había financiado 1 millón de proyectos; en el 77% de las escuelas públicas de los Estados Unidos, se ha solicitado al menos un proyecto a través de DonorsChoose.org. DonorsChoose ha compartido un conjunto de datos completo de todos los proyectos anteriores, los recursos relacionados, junto con los metadatos de profesores, escuelas, donantes y donaciones. Estos datos se pueden utilizar para extraer conocimientos ocultos y crear una solución que permita a DonorsChoose.org construir campañas de correo electrónico dirigidas, recomendando solicitudes de aulas específicas a donantes anteriores. En este cuaderno, he realizado un análisis y una exploración en profundidad del conjunto de datos compartido. Este cuaderno no solo proporciona información valiosa sobre el conjunto de datos de DonorsChoose, sino que también sirve como un tutorial para realizar análisis de datos / análisis exploratorio de datos (EDA) y visualizaciones de datos.

# %% [markdown]
# [1. Preparación del Conjunto de Datos](#1)
#
# [2. Explorando a los Donantes](#2)
# &thinsp;&thinsp;&thinsp;&thinsp; [2.1 Vista General de los Donantes](#2.1)
# &thinsp;&thinsp;&thinsp;&thinsp; [2.2 Donantes de diferentes Estados](#2.2)
# &thinsp;&thinsp;&thinsp;&thinsp; [2.3 Estados con la Mayor Proporción de Donantes por Población](#2.3)
# &thinsp;&thinsp;&thinsp;&thinsp; [2.4 Visualizando dónde se Ubican los Donantes](#2.5)
# &thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp; [- 2.4.1 Dónde se ubican los donantes en California](#2.4.1)
# &thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp; [- 2.4.2 Dónde se ubican los donantes en Florida](#2.4.2)
# &thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp; [- 2.4.3 Dónde se ubican los donantes en Nueva York](#2.4.3)
# &thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp; [- 2.4.4 Dónde se ubican los donantes en Texas](#2.4.4)
# &thinsp;&thinsp; &thinsp;&thinsp; [2.5 Dónde se Ubican los Donantes](#2.5)
# &thinsp;&thinsp;&thinsp;&thinsp; [2.6 Donantes Profesores y No Profesores a través de diferentes Estados](#2.6)
#
# [3. Explorando las Donaciones](#3)
# &thinsp;&thinsp;&thinsp;&thinsp; [3.1 Vista General de las Donaciones](#3.1)
# &thinsp;&thinsp;&thinsp;&thinsp; [3.2 Proyectos y their Donaciones](#3.2)
# &thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp; &thinsp;&thinsp; [- 3.2.1 Proyectos con el Mayor Número de Donantes](#3.2)
# &thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp; &thinsp;&thinsp; [- 3.2.2 Proyectos con los Mayores Montos Totales Financiados](#3.2)
# &thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp; &thinsp;&thinsp; [- 3.2.3 Proyectos con los Mayores Montos Promedio por Donante](#3.2)
# &thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp; &thinsp;&thinsp; [- 3.2.4 Proyectos con el Monto Máximo de una Sola Donación](#3.2)
#  &thinsp;&thinsp;&thinsp;&thinsp; [3.3 Los Donantes y sus Donaciones](#3.3)
# &thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp; &thinsp;&thinsp; [- 3.3.1 Donantes que han realizado el Mayor Número de Donaciones](#3.3)
# &thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp; &thinsp;&thinsp; [- 3.3.2 Donantes que han financiado los Mayores Montos Totales](#3.3)
# &thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp; &thinsp;&thinsp; [- 3.3.3 Donantes que financian los Mayores Montos Promedio en donaciones individuales](#3.3)
# &thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp; &thinsp;&thinsp; [- 3.3.4 Donantes que han financiado el Monto Máximo de una Sola Donación](#3.3)
# &thinsp;&thinsp; &thinsp;&thinsp; [3.4 Montos de Donación por Año, Mes, Día, Hora](#3.4)
# &thinsp;&thinsp; &thinsp;&thinsp; [3.5 Donaciones Opcionales y Donaciones de Donantes Profesores](#3.5)
# &thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp; &thinsp;&thinsp; [- 3.5.1 Número y Monto Promedio de Donación: Donaciones Opcionales](#3.5.1)
# &thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp; &thinsp;&thinsp; [- 3.5.2 Número y Monto Promedio de Donación: Donantes Profesores](#3.5.2)
#  &thinsp;&thinsp; &thinsp;&thinsp; [3.6 Qué Estado ha recibido el Mayor Monto de Donación](#3.6)
#  &thinsp;&thinsp; &thinsp;&thinsp; [3.7 Qué Estado recibe los Mayores Montos Promedio de Donación](#3.7)
#  &thinsp;&thinsp; &thinsp;&thinsp; [3.8 Los Estados y el Total de Donaciones Recibidas](#3.8)
#  &thinsp;&thinsp; &thinsp;&thinsp; [3.9 Donaciones desde California a lo largo del tiempo](#3.9)
#
# [4. Explorando a los Profesores](#4)
# &thinsp;&thinsp; &thinsp;&thinsp; [4.1 Vista General de los Datos de Profesores](#4.1)
# &thinsp;&thinsp; &thinsp;&thinsp; [4.2 Quiénes fueron los Primeros Profesores en DonorsChoose](#4.2)
# &thinsp;&thinsp; &thinsp;&thinsp; [4.3 Crecimiento en el Número de Profesores a lo largo de los años](#4.3)
# &thinsp;&thinsp; &thinsp;&thinsp; [4.4 Cuál es la distribución de los Prefijos de los Profesores](#4.4)
# &thinsp;&thinsp; &thinsp;&thinsp; [4.5 Serie Temporal de Profesores publicando sus primeros proyectos](#4.5)
#
# [5. Explorando las Escuelas](#5)
# &thinsp;&thinsp; &thinsp;&thinsp; [5.1 Vista General de los Datos de Escuelas](#5.1)
# &thinsp;&thinsp; &thinsp;&thinsp; [5.2 Qué Tipo de Zona Metropolitana tienen las Escuelas que publican proyectos (y Principales Estados y Ciudades)](#5.2)
# &thinsp;&thinsp; &thinsp;&thinsp; [5.3 Distribución del Porcentaje de Almuerzo Gratuito en las Escuelas](#5.3)
# &thinsp;&thinsp; &thinsp;&thinsp; [5.4 Qué tipos de escuelas están registradas en Mayoría](#5.4)
#
# [6. Explorando los Recursos](#6)
# &thinsp;&thinsp; &thinsp;&thinsp; [6.1 Vista General de los Datos de Recursos](#6.1)
# &thinsp;&thinsp; &thinsp;&thinsp; [6.2 ¿Qué artículos son los más populares en DonorsChoose?](#6.2)
# &thinsp;&thinsp; &thinsp;&thinsp; [6.3 ¿Cuáles son los artículos más caros?](#6.3)
# &thinsp;&thinsp; &thinsp;&thinsp; [6.4 ¿Quiénes son los proveedores más populares y cuál es el costo promedio asociado a ellos?](#6.4)
#
# [7. Explorando los Proyectos](#7)
# &thinsp;&thinsp; &thinsp;&thinsp; [7.1 Vista General de los Datos de Proyectos](#7.1)
# &thinsp;&thinsp; &thinsp;&thinsp; [7.2 Mayoría de Categorías, Subcategorías y Categorías de Recursos de los proyectos](#7.2)
# &thinsp;&thinsp; &thinsp;&thinsp; [7.3 Tipo de Proyecto y Estado del Proyecto](#7.3)
# &thinsp;&thinsp; &thinsp;&thinsp; [7.4 Día de Publicación y Día de Financiamiento](#7.4)
# &thinsp;&thinsp; &thinsp;&thinsp; [7.5 Trimestre de Publicación y Trimestre de Financiamiento](#7.5)
# &thinsp;&thinsp; &thinsp;&thinsp; [7.6 ¿En qué mes se publican la mayoría de los proyectos?](#7.6)
# &thinsp;&thinsp; &thinsp;&thinsp; [7.7 ¿Está aumentando el número de proyectos?](#7.7)
# &thinsp;&thinsp; &thinsp;&thinsp; [7.8 ¿En qué Año y Mes el costo del proyecto es el más alto?](#7.8)
# &thinsp;&thinsp; &thinsp;&thinsp; [7.9 ¿En qué Año y Categoría de Grado Escolar el costo del proyecto es el más alto?](#7.9)
# &thinsp;&thinsp; &thinsp;&thinsp; [7.10 ¿Para qué Categoría de Grado Escolar y Categoría de Recurso el costo del proyecto es el más alto?](#7.10)
# &thinsp;&thinsp; &thinsp;&thinsp; [7.11 Estado del Proyecto por Años](#7.11)
# &thinsp;&thinsp; &thinsp;&thinsp; [7.12 Duración de los Proyectos Financiados Exitosamente](#7.12)
# &thinsp;&thinsp; &thinsp;&thinsp; [7.13 Estado del Proyecto por diferentes Estados](#7.13)
# &thinsp;&thinsp; &thinsp;&thinsp; [7.14 Costo Promedio de los Proyectos por Tipo de Zona Metropolitana de la Escuela y Categoría de Recursos](#7.14)
# &thinsp;&thinsp; &thinsp;&thinsp; [7.15 Costo Promedio de los Proyectos por Tipo de Zona Metropolitana de la Escuela y Categoría de Nivel de Grado](#7.15)
#
#
# [8. Análisis de Texto de los Proyectos](#8)
# &thinsp;&thinsp; &thinsp;&thinsp; [8.1 Limpieza de Texto](#8.1)
# &thinsp;&thinsp; &thinsp;&thinsp; [8.2 Análisis de Bolsa de Palabras (Bag of Words)](#8.2)
# &thinsp;&thinsp; &thinsp;&thinsp; &thinsp;&thinsp; &thinsp;&thinsp; [8.2.1 Palabras clave / N-gramas principales utilizados por los profesores en todos los ensayos](#8.2.1)
# &thinsp;&thinsp; &thinsp;&thinsp; &thinsp;&thinsp; &thinsp;&thinsp; [8.2.2 Palabras clave / N-gramas principales utilizados en diferentes Estados](#8.2.2)
# &thinsp;&thinsp; &thinsp;&thinsp; &thinsp;&thinsp; &thinsp;&thinsp; [8.2.3 Contexto de "Mis Estudiantes Son ... "](#8.2.3)
# &thinsp;&thinsp; &thinsp;&thinsp; &thinsp;&thinsp; &thinsp;&thinsp; [8.2.4 Contexto de "Mis Estudiantes Necesitan ... "](#8.2.4)
# &thinsp;&thinsp; &thinsp;&thinsp; &thinsp;&thinsp; &thinsp;&thinsp; [8.2.5 Título del Proyecto - Principales Palabras Clave Utilizadas](#8.2.5)
#
#
# [9. Entendiendo y Comparando las Características de los Proyectos](#9)
# &thinsp;&thinsp; &thinsp;&thinsp; [9.1 Proyectos Expirados vs Financiados Exitosamente](#9.1)
# &thinsp;&thinsp; &thinsp;&thinsp; [9.2 Proyectos con Duración de Financiamiento Corta vs Larga](#9.2)
# &thinsp;&thinsp; &thinsp;&thinsp; [9.3 Proyectos con Donante Único vs Donantes Múltiples](#9.3)

# %% [markdown]
# ### 1. Preparación del conjunto de datos
#
# Importemos las bibliotecas necesarias y carguemos el conjunto de datos.

# %%
# !pip install wordcloud
from plotly.offline import init_notebook_mode, iplot
import plotly.graph_objs as go
import matplotlib.pyplot as plt
from plotly import tools
from datetime import date
import pandas as pd
import numpy as np 
import seaborn as sns
import random 
import warnings
import operator
from wordcloud import WordCloud

warnings.filterwarnings("ignore")
init_notebook_mode(connected=True)

path = "../Practica05/Datasets/"
donors_df = pd.read_csv(path+"Donors.csv")
donations_df = pd.read_csv(path+"Donations.csv")
teachers_df = pd.read_csv(path+"Teachers.csv")
# Out:
# ...
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.1.0.min"</script>

# %% [markdown]
# ## 2. Exploración de los donantes
# El conjunto de datos de donantes contiene información sobre cada persona que ha realizado al menos una donación en DonorsChoose, incluyendo datos como su ciudad, estado, código postal y si son docentes.

# %% [markdown]
# ## 2.1 Resumen de los donantes
# Echemos un vistazo a una muestra de las primeras filas del conjunto de datos de donantes.

# %%
###### total rows
# donors_df.shape

###### total cities 
# len(donors_df['Donor City'].value_counts())

# more than one donation
# t = donations_df['Donor ID'].value_counts().to_frame()
# len(t[t['Donor ID']>1])

donors_df.head(3)
# Out:
#                            Donor ID     Donor City Donor State  \
# 0  bdd640fb06671ad11c80317fa3b1799d  San Francisco  California
# 1  8b9d2434e465e150bd9c66b3ad3c2d6d       San Jose  California
# 2  9a1de644815ef6d13b8faa1837f8a88b  San Francisco  California
#
#   Donor Is Teacher  Donor Zip
# 0              Yes        114
# 1              Yes        105
# 2               No        728

# %% [markdown]
# A fecha de **abril de 2018**, DonorsChoose cuenta con un total de **2.122.640 donantes registrados**.
#
# Estos donantes provienen de **15.204 ciudades distintas** de Estados Unidos y de algunos otros países. De esta gran cantidad de donantes, **solo 552.941** (es decir, alrededor del **26 %**) **han realizado más de una donación**.
#
# Uno de los objetivos principales del desafío **«Data Science for Good»** es obtener información o recomendaciones relevantes que permitan **volver a motivar a los donantes** para que contribuyan de nuevo. Dado que hay aproximadamente **1.471.613 donantes que han realizado una única donación**, DonorsChoose tiene la **oportunidad de incentivar a estas personas** a efectuar una nueva aportación.

# %% [markdown]
# ## 2.2.1 Número de donantes por estado

# %%
# !pip install folium
import folium
from folium import plugins
from io import StringIO

# **Definición de los estados con sus respectivas latitudes y longitudes**
folium_statesll = StringIO("""State,Latitude,Longitude
Alabama,32.806671,-86.791130
Alaska,61.370716,-152.404419
Arizona,33.729759,-111.431221
Arkansas,34.969704,-92.373123
California,36.116203,-119.681564
Colorado,39.059811,-105.311104
Connecticut,41.597782,-72.755371
Delaware,39.318523,-75.507141
District of Columbia,38.897438,-77.026817
Florida,27.766279,-81.686783
Georgia,33.040619,-83.643074
Hawaii,21.094318,-157.498337
Idaho,44.240459,-114.478828
Illinois,40.349457,-88.986137
Indiana,39.849426,-86.258278
Iowa,42.011539,-93.210526
Kansas,38.526600,-96.726486
Kentucky,37.668140,-84.670067
Louisiana,31.169546,-91.867805
Maine,44.693947,-69.381927
Maryland,39.063946,-76.802101
Massachusetts,42.230171,-71.530106
Michigan,43.326618,-84.536095
Minnesota,45.694454,-93.900192
Mississippi,32.741646,-89.678696
Missouri,38.456085,-92.288368
Montana,46.921925,-110.454353
Nebraska,41.125370,-98.268082
Nevada,38.313515,-117.055374
New Hampshire,43.452492,-71.563896
New Jersey,40.298904,-74.521011
New Mexico,34.840515,-106.248482
New York,42.165726,-74.948051
North Carolina,35.630066,-79.806419
North Dakota,47.528912,-99.784012
Ohio,40.388783,-82.764915
Oklahoma,35.565342,-96.928917
Oregon,44.572021,-122.070938
Pennsylvania,40.590752,-77.209755
Rhode Island,41.680893,-71.511780
South Carolina,33.856892,-80.945007
South Dakota,44.299782,-99.438828
Tennessee,35.747845,-86.692345
Texas,31.054487,-97.563461
Utah,40.150032,-111.862434
Vermont,44.045876,-72.710686
Virginia,37.769337,-78.169968
Washington,47.400902,-121.490494
West Virginia,38.491226,-80.954453
Wisconsin,44.268543,-89.616508
Wyoming,42.755966,-107.302490""")

tempdf = states_df = donors_df['Donor State'].value_counts()
t1 = pd.DataFrame()
t1['Donor State'] = tempdf.index
t1['Donor Count'] = tempdf.values

# **tempdf = combined_df.groupby(['Donor State']).agg({'Donation Amount':'sum'}).reset_index()**
# **t1 = tempdf.sort_values('Donation Amount', ascending=False)**

sdf = pd.read_csv(folium_statesll).rename(columns={'State':'Donor State'})
sdf = sdf.merge(t1, on='Donor State', how='inner')
sdf

map4 = folium.Map(location=[39.50, -98.35], tiles='CartoDB dark_matter', zoom_start=3.5)

for j, rown in sdf.iterrows():
    rown = list(rown)
    # **Se traducen las etiquetas emergentes del mapa (popup) a "Estado:" y "Donantes:"**
    folium.CircleMarker([float(rown[1]), float(rown[2])], popup="<b>**Estado:**</b>" + rown[0].title() +"<br> <b>**Donantes:**** </b> "+str(int(rown[3])), radius=float(rown[3])*0.0001, color='#be0eef', fill=True).add_to(map4)

map4
# Out:
# ...
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %%
def bar_hor(df, col, title, color, w=None, h=None, lm=0, limit=100, return_trace=False, rev=False):
    cnt_srs = df[col].value_counts()
    yy = cnt_srs.head(limit).index[::-1] 
    xx = cnt_srs.head(limit).values[::-1] 
    if rev:
        yy = cnt_srs.tail(limit).index[::-1] 
        xx = cnt_srs.tail(limit).values[::-1] 
        
    trace = go.Bar(y=yy, x=xx, orientation = 'h', marker=dict(color=color))
    if return_trace:
        return trace 
    layout = dict(title=title, margin=dict(l=lm), width=w, height=h)
    data = [trace]
    fig = go.Figure(data=data, layout=layout)
    iplot(fig)

def bar_hor_noagg(x, y, title, color, w=None, h=None, lm=0, limit=100, rt=False):
    trace = go.Bar(y=x, x=y, orientation = 'h', marker=dict(color=color))
    if rt:
        return trace
    layout = dict(title=title, margin=dict(l=lm), width=w, height=h)
    data = [trace]
    fig = go.Figure(data=data, layout=layout)
    iplot(fig)

def bar_ver_noagg(x, y, title, color, w=None, h=None, lm=0, rt = False):
    trace = go.Bar(y=y, x=x, marker=dict(color=color))
    if rt:
        return trace
    layout = dict(title=title, margin=dict(l=lm), width=w, height=h)
    data = [trace]
    fig = go.Figure(data=data, layout=layout)
    iplot(fig)

# **Traducción de los títulos de las gráficas individuales**
trace1 = bar_hor(donors_df, 'Donor City', "**Principales ciudades con el máximo de donantes**", '#c2d2ed', 500, 400, 200, limit = 10, return_trace=True)
trace2 = bar_hor(donors_df, 'Donor State', "**Principales estados con el máximo de donantes**", '#c2d2ed', 500, 400, 200, limit = 10, return_trace=True)
trace4 = bar_hor(donors_df, 'Donor State', "**Principales estados con el máximo de donantes**", '#c2d2ed', 600, 400, 200, limit = 10, return_trace=True, rev=True)

# **Traducción de los títulos de las subgráficas (mínimos y máximos)**
fig = tools.make_subplots(rows=1, cols=2, print_grid=False, subplot_titles = ['**Estados con el máximo de donantes**','**Estados con el mínimo de donantes**'])
# fig = tools.make_subplots(rows=2, cols=2, specs=[[{}, {}], [{'colspan': 2}, None]], print_grid=False, subplot_titles = ['**Estados con el máximo de donantes**','**Estados con el mínimo de donantes**', '**Ciudades con el máximo de donantes**'])

fig.append_trace(trace2, 1, 1);
fig.append_trace(trace4, 1, 2);
# fig.append_trace(trace1, 2, 1);

fig['layout'].update(height=400, showlegend=False);
iplot(fig);

# %% [markdown]
# California, al ser el estado con mayor población, también cuenta con una gran base de donantes registrados con casi 300,000 donantes. San Francisco y Los Ángeles son las principales ciudades de California donde se encuentra el mayor número de donantes. El mayor número de escuelas y proyectos también proviene del estado de California.
#
# Nueva York, Texas y Florida, con aproximadamente 137,000, 134,000 y 108,000 donantes respectivamente, son otros tres estados principales con una alta población de donantes. Las ciudades principales incluyen Nueva York, Miami, Tampa, Houston y Dallas, donde se ubica la mayor cantidad de donantes.
#
# Dakota del Norte, Dakota del Sur, Vermont y Wyoming son los estados con un número muy bajo de donantes, menos de 4,000. Existe una entrada llamada "otros" en los datos de los estados, lo que probablemente indica donantes que son maestros o donantes de otros países.
#
# Entre todas las ciudades de EE. UU., las tres principales son: Chicago (aprox. 35K donantes), Nueva York (aprox. 27K donantes) y Brooklyn (aprox. 22K donantes) con el mayor número de donantes. Las ciudades californianas de San Francisco (SF) y Los Ángeles (LA) son las siguientes dos ciudades con una gran base de donantes, con aprox. 18K y aprox. 16K donantes respectivamente.

# %% [markdown]
# ## Conjunto de datos ajustado por población¶
# Los estados que encabezan los gráficos anteriores son, en realidad, aquellos con una población muy elevada. Resultaría interesante determinar el número de donantes por cada 100.000 habitantes en cada estado. He incorporado un conjunto de datos ajustado por población que incluye la población de cada estado correspondiente al año 2013.

# %% [markdown]
# ## 2.3 Estados con la mayor proporción de donantes por población

# %%
# Población por estado según el censo de 2013
census_2013 = {'Mississippi': 2991207, 'Iowa': 3090416, 'Oklahoma': 3850568, 'Delaware': 925749, 'Minnesota': 5420380, 'Alaska': 735132, 'Illinois': 12882135, 'Arkansas': 2959373, 'New Mexico': 2085287, 'Indiana': 6570902, 'Maryland': 5928814, 'Louisiana': 4625470, 'Texas': 26448193, 'Wyoming': 582658, 'Arizona': 6626624, 'Wisconsin': 5742713, 'Michigan': 9895622, 'Kansas': 2893957, 'Utah': 2900872, 'Virginia': 8260405, 'Oregon': 3930065, 'Connecticut': 3596080, 'New York': 19651127, 'California': 38332521, 'Massachusetts': 6692824, 'West Virginia': 1854304, 'South Carolina': 4774839, 'New Hampshire': 1323459, 'Vermont': 626630, 'Georgia': 9992167, 'North Dakota': 723393, 'Pennsylvania': 12773801, 'Florida': 19552860, 'Hawaii': 1404054, 'Kentucky': 4395295, 'Rhode Island': 1051511, 'Nebraska': 1868516, 'Missouri': 6044171, 'Ohio': 11570808, 'Alabama': 4833722, 'South Dakota': 844877, 'Colorado': 5268367, 'Idaho': 1612136, 'New Jersey': 8899339, 'Washington': 6971406, 'North Carolina': 9848060, 'Tennessee': 6495978, 'Montana': 1015165, 'District of Columbia': 646449, 'Nevada': 2790136, 'Maine': 1328302}

# Contar la cantidad de donantes por estado a partir del DataFrame original
donors_from_states = dict(donors_df['Donor State'].value_counts())

don_pop = {}
for state, don in donors_from_states.items():
    # Si el estado no está en el diccionario del censo, se ignora
    if state not in census_2013:
        continue
    # Calcular la tasa de donantes por cada 100,000 habitantes
    don_pop[state] = float(don) * 100000 / census_2013[state]

import operator
# Ordenar los estados de mayor a menor según su tasa de donantes
don_pop = sorted(don_pop.items(), key=operator.itemgetter(1), reverse=True)

# Extraer los nombres de los estados (xx) y las tasas (yy), omitiendo el primer elemento [1:]
xx = [x[0] for x in (don_pop)][1:]
yy = [x[1] for x in (don_pop)][1:]

# Configurar el gráfico de barras con Plotly
trace2 = go.Bar(
    x=xx,
    y=yy,
    name='Donantes por población',
    marker=dict(color='green'),
    opacity=0.3)

data = [trace2]

# Configurar el diseño (layout) del gráfico
layout = go.Layout(
    barmode='group',
    legend=dict(dict(x=-.1, y=1.2)),
    margin=dict(b=120),
    title='Estados con la mayor proporción de donantes por población',)

# Crear y mostrar la figura
fig = go.Figure(data=data, layout=layout)
iplot(fig, filename='barras-agrupadas')

# %% [markdown]
# Resulta interesante observar que los estados de Carolina del Sur (con una población de 4 774 839), Massachusetts (con 6 692 824) y Connecticut (con 3 596 080) presentan la mayor proporción de donantes respecto a la población, así como el mayor número de donantes por cada 100 000 habitantes: Carolina del Sur registra 985 donantes; Massachusetts, 907; y Connecticut, 878.
# Por el contrario, Wyoming, Nebraska y Nuevo México presentan las cifras más bajas de donantes por cada 100 000 habitantes, con 285, 335 y 363 donantes, respectivamente.
# Texas, uno de los estados con mayor número total de donantes, tiene una proporción menor de donantes en relación con su población: 508 donantes por cada 100 000 habitantes.

# %% [markdown]
# ## 2.4 Visualicemos dónde se encuentran los donantes.

# %% [markdown]
# ## 2.4.1 Donde se encuentran las donantes en California

# %%
import io
import pandas as pd
import folium
from folium import plugins

# Datos de ciudades en formato CSV (guardados en una cadena de texto)
calcit = io.StringIO(u"""Name,Latitude,Longitude,Total Donors,Color,Size
Los Angeles,34.052233,-118.243686,"17,922.000000",#0061ff,10
San Francisco,37.774931,-122.419417,"16,553.000000",#0061ff,10
San Diego,32.715328,-117.157256,"9,072.000000",#0061ff,10
... [El resto de tus datos de ciudades se mantiene igual] ...
Westmorland,33.037267,-115.621383,1.000000,#f9e84a,1
""")

# Cargar los datos en un DataFrame de Pandas
ciudades = pd.read_csv(calcit)

# Limpiar los datos eliminando filas que contengan valores nulos (NaN)
ciudades = ciudades.dropna()

# --- CÓDIGO COMENTADO ORIGINAL (Marcadores Circulares) ---
# mapa_osm = folium.Map(location=[36.611617,-119.527072], zoom_start=5)
# for i, fila in ciudades.iterrows():
#     folium.CircleMarker([fila['Latitude'], fila['Longitude']],
#                         radius=fila['Size'],
#                         color=fila['Color'],
#                         fill_color=fila['Color'],
#                        ).add_to(mapa_osm)

# Crear un mapa base interactivo centrado en California
# Se utiliza el estilo oscuro 'cartodbdark_matter' y un zoom inicial de 6
mapa_osm2 = folium.Map([36.611617, -119.527072], zoom_start=6, tiles='cartodbdark_matter')

# Lista para almacenar las coordenadas y la intensidad (número de donantes) para el mapa de calor
arreglo_coordenadas = []

# Iterar sobre cada ciudad para procesar los datos
for i, fila in ciudades.iterrows():
    # Es necesario limpiar la columna 'Total Donors':
    # 1. Se asegura de que sea texto (.astype(str)) para evitar errores si ya hay números.
    # 2. Se eliminan las comas de los millares con .replace(",", "").
    # 3. Se convierte a número flotante (float).
    total_donantes = float(str(fila['Total Donors']).replace(",", ""))
    
    # Añadir al arreglo: [Latitud, Longitud, Peso/Intensidad]
    arreglo_coordenadas.append([fila['Latitude'], fila['Longitude'], total_donantes])

# Generar y añadir la capa del Mapa de Calor (HeatMap) al mapa base
mapa_osm2.add_child(plugins.HeatMap(arreglo_coordenadas, radius=12))

# Mostrar el mapa resultante
mapa_osm2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %% [markdown]
# - Los Angeles, 17,922
# - San Francisco, 16,553
# - San Diego, 9,072
# - San Jose, 7,674
# - Oakland, 6,783
